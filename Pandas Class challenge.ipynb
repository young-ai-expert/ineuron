# %%
import pandas as pd

# %%
chipotle = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

# %%
beer_ = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt'

# %%
crimerate = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv'

# %%
dataset = 'https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv'

# %%
chip = pd.read_csv(chipotle, sep = '\t')

# %%
beer = pd.read_csv(beer_ , sep = ' ')

# %%
crime = pd.read_csv(crimerate)

# %%
data = pd.read_csv(dataset)

# %%
chip.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
beer.head()
# Out:
#           name  calories  sodium  alcohol  cost
# 0    Budweiser       144      15      4.7  0.43
# 1      Schlitz       151      19      4.9  0.43
# 2    Lowenbrau       157      15      0.9  0.48
# 3  Kronenbourg       170       7      5.2  0.73
# 4     Heineken       152      11      5.0  0.77

# %%
crime.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
data.head()
# Out:
#   Package           Item                                              Title  \
# 0     AER        Affairs                   Fair's Extramarital Affairs Data
# 1     AER   ArgentinaCPI                  Consumer Price Index in Argentina
# 2     AER      BankWages                                         Bank Wages
# 3     AER  BenderlyZwick  Benderly and Zwick Data: Inflation, Growth and...
# 4     AER      BondYield                                    Bond Yield Data
#
#    Rows  Cols  n_binary  n_character  n_factor  n_logical  n_numeric  \
# 0   601     9         2            0         2          0          7
# 1    80     2         0            0         0          0          2
# 2   474     4         2            0         3          0          1
# 3    31     5         0            0         0          0          5
# 4    60     2         0            0         0          0          2
#
#                                                  CSV  \
# ...

# %%
# Chipotle

# %%
chip.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
chip['item_price']
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
l = []
for i in range(len(chip['item_price'])):
    l.append(float(chip['item_price'][i][1:]))

# %%
chip['item_price'] = l

# %%
chip.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
import numpy as np

# %%
for i in chip['choice_description']:
    print(i)
# Out:
# nan
# [Clementine]
# [Apple]
# nan
# [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
# [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Guacamole, Lettuce]]
# nan
# [Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Pinto Beans, Cheese, Sour Cream, Guacamole, Lettuce]]
# [Tomatillo Green Chili Salsa, [Pinto Beans, Cheese, Sour Cream, Lettuce]]
# [Fresh Tomato Salsa, [Rice, Black Beans, Pinto Beans, Cheese, Sour Cream, Lettuce]]
# nan
# [Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream]]
# [Roasted Chili Corn Salsa, [Rice, Black Beans, Cheese, Sour Cream]]
# [Fresh Tomato Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Guacamole]]
# nan
# nan
# [Tomatillo-Green Chili Salsa (Medium), [Pinto Beans, Cheese, Sour Cream]]
# [Fresh Tomato Salsa (Mild), [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]
# [Sprite]
# [Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Sour Cream, Cheese, Lettuce]]
# ...

# %%
chip['choice_description'][8]
# Out:
# '[Tomatillo Green Chili Salsa, [Pinto Beans, Cheese, Sour Cream, Lettuce]]'

# %%
chip['choice_description'][8][:][]
# Out:
# '[Tomatillo Green Chili Salsa, [Pinto Beans, Cheese, Sour Cream, Lettuce]]'

# %%
fre = chip.groupby('order_id')

# %%
frequency = pd.DataFrame(fre)

# %%
chip['item_name'].describe()
# Out:
# count             4622
# unique              50
# top       Chicken Bowl
# freq               726
# Name: item_name, dtype: object

# %%
unique_ = pd.Series(chip['item_name'].unique())

# %%
beer.head()
# Out:
#           name  calories  sodium  alcohol  cost
# 0    Budweiser       144      15      4.7  0.43
# 1      Schlitz       151      19      4.9  0.43
# 2    Lowenbrau       157      15      0.9  0.48
# 3  Kronenbourg       170       7      5.2  0.73
# 4     Heineken       152      11      5.0  0.77

# %%
len(beer)
# Out:
# 20

# %%
beer['sodium']
# Out:
# 0     15
# 1     19
# 2     15
# 3      7
# 4     11
# 5     23
# 6     24
# 7     27
# 8     10
# 9      8
# 10    18
# 11    15
# 12    11
# 13    19
# 14     6
# 15    15
# 16    19
# 17    24
# 18     6
# 19     7
# Name: sodium, dtype: int64

# %%
beer['Sodium_content'] = beer['sodium']

# %%
beer['Sodium_content'] = l

# %%
l = []
for i in beer['sodium']:
    if i > 14:
        l.append('High')
    else:
        l.append('Low')

# %%
beer
# Out:
#                     name  calories  sodium  alcohol  cost Sodium_content
# 0              Budweiser       144      15      4.7  0.43           High
# 1                Schlitz       151      19      4.9  0.43           High
# 2              Lowenbrau       157      15      0.9  0.48           High
# 3            Kronenbourg       170       7      5.2  0.73            Low
# 4               Heineken       152      11      5.0  0.77            Low
# 5          Old_Milwaukee       145      23      4.6  0.28           High
# 6             Augsberger       175      24      5.5  0.40           High
# 7   Srohs_Bohemian_Style       149      27      4.7  0.42           High
# 8            Miller_Lite        99      10      4.3  0.43            Low
# 9        Budweiser_Light       113       8      3.7  0.40            Low
# 10                 Coors       140      18      4.6  0.44           High
# 11           Coors_Light       102      15      4.1  0.46           High
# ...

# %%
beer['Developing beer potomania'] = [ 0 if i =='Low' else 1 for i in beer['Sodium_content']]

# %%
beer
# Out:
#                     name  calories  sodium  alcohol  cost Sodium_content  \
# 0              Budweiser       144      15      4.7  0.43           High
# 1                Schlitz       151      19      4.9  0.43           High
# 2              Lowenbrau       157      15      0.9  0.48           High
# 3            Kronenbourg       170       7      5.2  0.73            Low
# 4               Heineken       152      11      5.0  0.77            Low
# 5          Old_Milwaukee       145      23      4.6  0.28           High
# 6             Augsberger       175      24      5.5  0.40           High
# 7   Srohs_Bohemian_Style       149      27      4.7  0.42           High
# 8            Miller_Lite        99      10      4.3  0.43            Low
# 9        Budweiser_Light       113       8      3.7  0.40            Low
# 10                 Coors       140      18      4.6  0.44           High
# 11           Coors_Light       102      15      4.1  0.46           High
# ...

# %%
crime.tail()
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 50  2010   309330219  10363873  1251248   9112625   14772          85593
# 51  2011   311587816  10258774  1206031   9052743   14661          84175
# 52  2012   313873685  10219059  1217067   9001992   14866          85141
# 53  2013   316497531   9850445  1199684   8650761   14319          82109
# 54  2014   318857056   9475816  1197987   8277829   14249          84041
#
#     Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft  \
# 50   369089              781844   2168457        6204601         739565
# 51   354772              752423   2185140        6151095         716508
# 52   355051              762009   2109932        6168874         723186
# 53   345095              726575   1931835        6018632         700294
# 54   325802              741291   1729806        5858496         689527
#
#       theft  Population_not_affected  Lifelost
# ...

# %%
crime['theft'] = crime['Larceny_Theft']+crime['Vehicle_Theft']

# %%
crime['Population_not_affected'] = crime['Population']-crime['Total']

# %%
crime['Lifelost'] = crime['Murder']+crime['Aggravated_assault']+crime['Forcible_Rape']

# %%
crime.loc[crime['Total'] == max(crime['Total'])]
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 31  1991   252177000  14872900  1911770  12961100   24700         106590
#
#     Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft  \
# 31   687730             1092740   3157200        8142200        1661700
#
#       theft  Population_not_affected  Lifelost
# 31  9803900                237304100   1224030

# %%
gk = data.groupby('Title')

# %%
gk.first()
# Out:
#                                                        Package         Item  \
# Title
# "Let Them Watch TV"                                  stevedata         LTWT
# 'May' in Federalist Papers                                 vcd   Federalist
# 'colors()' in Luv space                                ggplot2  luv_colours
# 100 m Swimming World Records                        mosaicData  SwimRecords
# 12 cognitive variables from Cattell (1963)               psych      cattell
# ...                                                        ...          ...
# smoking                                                  COUNT      smoking
# sorption data set                                         DAAG     sorption
# titanic                                                  COUNT      titanic
# titanicgrp                                               COUNT   titanicgrp
# van Langren's Data on Longitude Distance betwee...    HistData  Langren.all
#
# ...

# %%
data['Title'].unique()
# Out:
# array(["Fair's Extramarital Affairs Data",
#        'Consumer Price Index in Argentina', 'Bank Wages', ...,
#        'Von Bortkiewicz Horse Kicks Data', "Weldon's Dice Data",
#        'Women in Queues'], dtype=object)

# %%
data['Title'].describe()
# Out:
# count                           1714
# unique                          1580
# top       Internal functions for gap
# freq                              18
# Name: Title, dtype: object

# %%
data.head()
# Out:
#   Package           Item                                              Title  \
# 0     AER        Affairs                   Fair's Extramarital Affairs Data
# 1     AER   ArgentinaCPI                  Consumer Price Index in Argentina
# 2     AER      BankWages                                         Bank Wages
# 3     AER  BenderlyZwick  Benderly and Zwick Data: Inflation, Growth and...
# 4     AER      BondYield                                    Bond Yield Data
#
#    Rows  Cols  n_binary  n_character  n_factor  n_logical  n_numeric  \
# 0   601     9         2            0         2          0          7
# 1    80     2         0            0         0          0          2
# 2   474     4         2            0         3          0          1
# 3    31     5         0            0         0          0          5
# 4    60     2         0            0         0          0          2
#
#                                                  CSV  \
# ...

# %%
pack = data.groupby('Package')

# %%
pack.first()
# Out:
#                             Item  \
# Package
# AER                      Affairs
# COUNT                    affairs
# DAAG                        ACF1
# Ecdat                   Accident
# HLMdiag                      ahd
# HSAUR                     agefat
# HistData               Arbuthnot
# ISLR                        Auto
# KMsurv                      aids
# MASS                       abbey
# Stat2Data            AccordPrice
# boot                        acme
# carData                    Adler
# causaldata              abortion
# cluster              agriculture
# datasets             ability.cov
# dplyr           band_instruments
# dragracer            rpdr_contep
# drc                       acidiq
# evir                         bmw
# forecast                     gas
# fpp2                         a10
# gap                        aldh2
# geepack                   dietox
# ggplot2                 diamonds
# ggplot2movies             movies
# gt                   countrypops
# ...
